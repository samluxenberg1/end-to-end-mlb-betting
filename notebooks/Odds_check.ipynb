# %%
import os
import sys

sys.path.append(os.path.dirname(os.getcwd())) 
import logging 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.features.load_games_from_db import load_games_from_db

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
path = '../data/processed_game_odds.csv'
df_odds = pd.read_csv(path)

# %%
df_odds.shape
# Out:
# (13691, 8)

# %%
df_games = load_games_from_db()
# Out:
# 2025-07-21 21:57:04,253 [INFO] Successully loaded 10983 games from database
# There are 10983 games for  modeling...

# %%
scored_data_path = '../src/scoring/output.csv'
df_scored = pd.read_csv(scored_data_path)

# %%
def keep_preferred_bookmaker(group, preferred_bookmakers):

    # Filter to same_time and preferred bookmaker
    same_time_bookmaker_preferred = group[(group['time_match']==1) & (group['bookmaker'].isin(preferred_bookmakers))]

    # Filter to preferred bookmaker
    bookmaker_preferred = group[group['bookmaker'].isin(preferred_bookmakers)]

    if len(same_time_bookmaker_preferred) > 0:
        # Keep first preferred bookmaker where time matches
        return same_time_bookmaker_preferred.iloc[[0]]
    
    elif len(same_time_bookmaker_preferred) == 0 and len(bookmaker_preferred) > 0: 
        # Keep first preferred bookmaker
        return bookmaker_preferred.iloc[[0]]
    
    else:
        # If no preferred bookmaker, keep all rows for this game_id
        return group


def join_odds_to_scored_data(df_scored: pd.DataFrame, df_odds: pd.DataFrame) -> pd.DataFrame:

    logging.info(f"Earliest Date in Scored Data: {df_scored['game_date'].min()}, Latest Date in Scored Data: {df_scored['game_date'].max()}")
    logging.info(f"Earliest Date in Odds Data: {df_odds['game_date'].min()}, Latest Date in Odds Data: {df_odds['game_date'].max()}")

    # Convert to datetime
    df_scored['game_date_time'] = pd.to_datetime(df_scored['game_date_time'], utc=True)
    df_scored['game_date'] = pd.to_datetime(df_scored['game_date'], utc=True)
    df_odds['game_date'] = pd.to_datetime(df_odds['game_date'], utc=True)
    df_odds['commence_time'] = pd.to_datetime(df_odds['commence_time'], utc=True)
    df_odds['timestamp'] = pd.to_datetime(df_odds['timestamp'], utc=True)

    # Join odds data to scored data
    odds_cols = ['timestamp','game_date','commence_time','home_team','away_team','bookmaker','home_odds','away_odds']
    logging.info(f"df_score Shape BEFORE Join: {df_scored.shape}")
    logging.info(f"df_scored # Unique Games BEFORE Join: {df_scored['game_id'].nunique()}")
    df_scored = df_scored.merge(
        df_odds[odds_cols],
        how='left',
        on=['game_date','home_team','away_team'], # will produce duplicate rows for double-headers (ok for now...)
        suffixes=('','_odds'),
        indicator=True
        )
    logging.info(f"df_score Shape AFTER Join: {df_scored.shape}")
    logging.info(f"df_scored # Unique Games AFTER Join: {df_scored['game_id'].nunique()}")

    logging.info(f"Join Match Rate: {df_scored['_merge'].value_counts(dropna=False, normalize=True).round(3)}")
    df_scored.drop('_merge', axis=1, inplace=True)

    # Dedup based on approximate times and selecting preferred bookmaker
    print(f"game_date_time: {df_scored['game_date_time'].iloc[0]}, dtype: {df_scored['game_date_time'].dtype}")
    print(f"commence_time: {df_scored['commence_time'].iloc[0]}, dtype: {df_scored['commence_time'].dtype}")
        
    df_scored['time_diff'] = (df_scored['game_date_time']-df_scored['commence_time']).dt.total_seconds()/60 # difference in minutes
    df_scored['time_match'] = (df_scored['time_diff'].abs() < 10).astype(int) # times within 10 minutes of each other are the same
    
    PREFERRED_BOOKMAKERS = ["betmgm", "draftkings", "fanduel", "williamhill_us", "espnbet"]
    df_scored['preferred_bookmaker'] = df_scored['bookmaker'].isin(PREFERRED_BOOKMAKERS).astype(int)

    df_scored = (
        df_scored
        .groupby('game_id')
        .apply(keep_preferred_bookmaker, PREFERRED_BOOKMAKERS, include_groups=False)
        .reset_index()
        .drop('level_1', axis=1)
    )

    logging.info(f"df_scored Shape AFTER Deduplication: {df_scored.shape}")
    logging.info(f"df_scored # Unique Games AFTER Join: {df_scored['game_id'].nunique()}")

    return df_scored

# %%
df_scored[['game_id','game_date','game_date_time']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10983 entries, 0 to 10982
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   game_id         10983 non-null  int64
#  1   game_date       10983 non-null  datetime64[ns]
#  2   game_date_time  10983 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 257.5+ KB

# %%
df_scored = join_odds_to_scored_data(df_scored=df_scored, df_odds=df_odds)
# Out:
# 2025-07-21 22:07:34,286 [INFO] Earliest Date in Scored Data: 2021-04-01 00:00:00+00:00, Latest Date in Scored Data: 2025-07-21 00:00:00+00:00
# 2025-07-21 22:07:34,289 [INFO] Earliest Date in Odds Data: 2021-04-01 00:00:00+00:00, Latest Date in Odds Data: 2025-07-20 00:00:00+00:00
# 2025-07-21 22:07:34,396 [INFO] df_score Shape BEFORE Join: (10983, 195)
# 2025-07-21 22:07:34,397 [INFO] df_scored # Unique Games BEFORE Join: 10983
# 2025-07-21 22:07:34,488 [INFO] df_score Shape AFTER Join: (14005, 201)
# 2025-07-21 22:07:34,489 [INFO] df_scored # Unique Games AFTER Join: 10983
# 2025-07-21 22:07:34,490 [INFO] Join Match Rate: _merge
# both          0.855
# left_only     0.145
# right_only    0.000
# Name: proportion, dtype: float64
# game_date_time: 2021-04-01 17:05:00+00:00, dtype: datetime64[ns, UTC]
# commence_time: 2021-04-01 17:05:00+00:00, dtype: datetime64[ns, UTC]
# 2025-07-21 22:07:44,313 [INFO] df_scored Shape AFTER Deduplication: (10983, 203)
# 2025-07-21 22:07:44,313 [INFO] df_scored # Unique Games AFTER Join: 10983

# %%
df_games['game_date'].min(), df_games['game_date'].max()
# Out:
# (Timestamp('2021-04-01 00:00:00'), Timestamp('2025-07-21 00:00:00'))

# %%
df_odds['game_date'].min(), df_odds['game_date'].max()
# Out:
# (Timestamp('2021-04-01 00:00:00'), Timestamp('2025-07-20 00:00:00'))

# %%
df_odds.sort_values('commence_time', inplace=True)

# %%
df_odds[df_odds['game_date']=='2025-06-20']
# Out:
#                  timestamp   game_date              home_team  \
# 8084  2025-06-19T12:55:37Z  2025-06-20      Oakland Athletics
# 8085  2025-06-19T12:55:37Z  2025-06-20    Los Angeles Dodgers
# 5829  2025-06-20T12:55:37Z  2025-06-20           Chicago Cubs
# 5830  2025-06-20T12:55:37Z  2025-06-20     Pittsburgh Pirates
# 5831  2025-06-20T12:55:37Z  2025-06-20       New York Yankees
# 5832  2025-06-20T12:55:37Z  2025-06-20         Tampa Bay Rays
# 5833  2025-06-20T12:55:37Z  2025-06-20      Toronto Blue Jays
# 5834  2025-06-20T12:55:37Z  2025-06-20          Miami Marlins
# 5835  2025-06-20T12:55:37Z  2025-06-20  Philadelphia Phillies
# 5836  2025-06-20T12:55:37Z  2025-06-20    St. Louis Cardinals
#
#               away_team         commence_time       bookmaker  home_odds  \
# 8084     Houston Astros  2025-06-20T02:06:00Z         fanduel        110
# 8085   San Diego Padres  2025-06-20T02:11:00Z         fanduel       -250
# 5829   Seattle Mariners  2025-06-20T18:21:00Z         fanduel       -134
# 5830      Texas Rangers  2025-06-20T22:41:00Z         fanduel        154
# 5831  Baltimore Orioles  2025-06-20T23:06:00Z         fanduel       -225
# 5832     Detroit Tigers  2025-06-20T23:06:00Z         fanduel       -110
# 5833  Chicago White Sox  2025-06-20T23:07:00Z         fanduel       -205
# 5834     Atlanta Braves  2025-06-20T23:11:00Z         fanduel        122
# 5835      New York Mets  2025-06-20T23:15:00Z  williamhill_us       -190
# 5836    Cincinnati Reds  2025-06-20T23:16:00Z         fanduel       -142
#
#       away_odds
# 8084       -130
# 8085        205
# 5829        116
# 5830       -184
# 5831        188
# 5832       -106
# 5833        172
# 5834       -144
# 5835        158
# 5836        120

# %%
df_games['game_date'] = pd.to_datetime(df_games['game_date'])
df_games[df_games['game_date'] ==pd.Timestamp('2025-06-20')]
# Out:
#        game_id  game_date            game_date_time  home_team_id  \
# 10626   777436 2025-06-20 2025-06-20 18:20:00+00:00           112
# 10627   777432 2025-06-20 2025-06-20 22:40:00+00:00           134
# 10628   777431 2025-06-20 2025-06-20 23:05:00+00:00           139
# 10629   777438 2025-06-20 2025-06-20 23:05:00+00:00           147
# 10630   777435 2025-06-20 2025-06-20 23:07:00+00:00           141
# 10631   777439 2025-06-20 2025-06-20 23:10:00+00:00           146
# 10632   777433 2025-06-20 2025-06-20 23:15:00+00:00           138
# 10633   777437 2025-06-20 2025-06-20 23:15:00+00:00           143
# 10634   777434 2025-06-20 2025-06-21 00:10:00+00:00           142
# 10635   777430 2025-06-20 2025-06-21 00:40:00+00:00           115
# 10636   777428 2025-06-20 2025-06-21 01:38:00+00:00           108
# 10637   777426 2025-06-20 2025-06-21 01:40:00+00:00           135
# 10638   777429 2025-06-20 2025-06-21 02:05:00+00:00           133
# 10639   777427 2025-06-20 2025-06-21 02:10:00+00:00           119
# 10640   777425 2025-06-20 2025-06-21 02:15:00+00:00           137
#
#        away_team_id              home_team             away_team  home_score  \
# 10626           136           Chicago Cubs      Seattle Mariners         4.0
# 10627           140     Pittsburgh Pirates         Texas Rangers         2.0
# 10628           116         Tampa Bay Rays        Detroit Tigers        14.0
# 10629           110       New York Yankees     Baltimore Orioles         3.0
# 10630           145      Toronto Blue Jays     Chicago White Sox         1.0
# 10631           144          Miami Marlins        Atlanta Braves         6.0
# 10632           113    St. Louis Cardinals       Cincinnati Reds         6.0
# 10633           121  Philadelphia Phillies         New York Mets        10.0
# 10634           158        Minnesota Twins     Milwaukee Brewers         6.0
# 10635           109       Colorado Rockies  Arizona Diamondbacks         8.0
# 10636           117     Los Angeles Angels        Houston Astros         2.0
# 10637           118       San Diego Padres    Kansas City Royals         5.0
# 10638           114              Athletics   Cleveland Guardians         5.0
# 10639           120    Los Angeles Dodgers  Washington Nationals         6.0
# 10640           111   San Francisco Giants        Boston Red Sox         5.0
#
#        away_score  state                         venue game_type
# 10626         9.0  Final                 Wrigley Field         R
# 10627         6.0  Final                      PNC Park         R
# 10628         8.0  Final  George M. Steinbrenner Field         R
# 10629         5.0  Final                Yankee Stadium         R
# 10630         7.0  Final                 Rogers Centre         R
# 10631         2.0  Final                loanDepot park         R
# 10632         1.0  Final                 Busch Stadium         R
# 10633         2.0  Final            Citizens Bank Park         R
# 10634        17.0  Final                  Target Field         R
# 10635        14.0  Final                   Coors Field         R
# 10636         3.0  Final                 Angel Stadium         R
# 10637         6.0  Final                    Petco Park         R
# 10638         1.0  Final            Sutter Health Park         R
# 10639         5.0  Final                Dodger Stadium         R
# 10640         7.0  Final                   Oracle Park         R

# %%
df_games['game_date'] = pd.to_datetime(df_games['game_date'])
df_odds['game_date'] = pd.to_datetime(df_odds['game_date'])
df_odds['commence_time'] = pd.to_datetime(df_odds['commence_time'], utc=True)
df_odds['timestamp'] = pd.to_datetime(df_odds['timestamp'], utc=True)

# %%
def keep_preferred_bookmaker(group, preferred_bookmakers):
    # Filter to same_time == 1 and preferred bookmakers
    same_time_preferred = group[(group['time_match'] == 1) & 
                               (group['bookmaker'].isin(preferred_bookmakers))]

    in_preferred_bookmaker = group[group['bookmaker'].isin(preferred_bookmakers)]
    
    if len(same_time_preferred) > 0:
        # Keep the first preferred bookmaker where time matches
        return same_time_preferred.iloc[[0]]
    elif len(same_time_preferred) == 0 and len(in_preferred_bookmaker) > 0:
        # Keep the first preferred bookmaker
        return in_preferred_bookmaker.iloc[[0]]
    else:
        # If no preferred bookmaker with same_time==1, keep all rows for this game_id
        return group

# %%
df_games_m = df_games.merge(df_odds[['timestamp','game_date','commence_time','home_team','away_team','bookmaker', 'home_odds','away_odds']],
                          how='left',
                          left_on=['game_date', 'home_team', 'away_team'],
                          right_on=['game_date','home_team','away_team'],
                          suffixes=('','_odds'), 
                            indicator=True
                         )

# %%
df_games.shape, df_games_m.shape
# Out:
# ((10983, 12), (13987, 18))

# %%
df_games_m['time_diff'] = (df_games_m['game_date_time'] - df_games_m['commence_time']).dt.total_seconds()/60
df_games_m['time_match'] = (df_games_m['time_diff'].abs() < 10).astype(int)
PREFERRED_BOOKMAKERS = ["betmgm", "draftkings", "fanduel", "williamhill_us", "espnbet"]
df_games_m['preferred_bookmaker'] = df_games_m['bookmaker'].isin(PREFERRED_BOOKMAKERS).astype(int)

# %%
df_dedup = df_games_m.groupby('game_id').apply(keep_preferred_bookmaker, PREFERRED_BOOKMAKERS, include_groups=False).reset_index().drop('level_1', axis=1)

# %%
df_dedup.shape
# Out:
# (10983, 21)

# %%
df_dedup['game_id'].nunique()
# Out:
# 10983

# %%
df_dedup.head(2)
# Out:
#    game_id  game_date            game_date_time  home_team_id  away_team_id  \
# 0   632169 2021-04-10 2021-04-10 20:05:00+00:00           137           115
# 1   632170 2021-04-11 2021-04-11 18:10:00+00:00           145           118
#
#               home_team           away_team  home_score  away_score  state  \
# 0  San Francisco Giants    Colorado Rockies         4.0         3.0  Final
# 1     Chicago White Sox  Kansas City Royals         3.0         4.0  Final
#
#                    venue game_type                 timestamp  \
# 0            Oracle Park         R 2021-04-10 12:55:00+00:00
# 1  Guaranteed Rate Field         R 2021-04-11 12:55:00+00:00
#
#               commence_time       bookmaker  home_odds  away_odds _merge  \
# 0 2021-04-10 20:05:00+00:00  williamhill_us     -179.0      162.0   both
# 1 2021-04-11 18:10:00+00:00  williamhill_us     -130.0      120.0   both
#
#    time_diff  time_match  preferred_bookmaker
# 0        0.0           1                    1
# 1        0.0           1                    1

# %%
df_dedup['_merge'].value_counts(dropna=False), df_dedup['_merge'].value_counts(dropna=False, normalize=True)
# Out:
# (_merge
#  both          9003
#  left_only     1980
#  right_only       0
#  Name: count, dtype: int64,
#  _merge
#  both          0.819721
#  left_only     0.180279
#  right_only    0.000000
#  Name: proportion, dtype: float64)

# %%
df_games_m[['game_id','game_date','game_date_time','commence_time','home_team','away_team','home_odds','away_odds','bookmaker', '_merge']].head()
# Out:
#    game_id  game_date            game_date_time             commence_time  \
# 0   634642 2021-04-01 2021-04-01 17:05:00+00:00 2021-04-01 17:05:00+00:00
# 1   634645 2021-04-01 2021-04-01 17:10:00+00:00 2021-04-01 17:10:00+00:00
# 2   634638 2021-04-01 2021-04-01 18:10:00+00:00 2021-04-01 18:10:00+00:00
# 3   634634 2021-04-01 2021-04-01 18:20:00+00:00 2021-04-01 18:20:00+00:00
# 4   634622 2021-04-01 2021-04-01 19:05:00+00:00 2021-04-01 19:05:00+00:00
#
#                home_team           away_team  home_odds  away_odds  \
# 0       New York Yankees   Toronto Blue Jays     -185.0      165.0
# 1         Detroit Tigers   Cleveland Indians      165.0     -189.0
# 2      Milwaukee Brewers     Minnesota Twins     -110.0      100.0
# 3           Chicago Cubs  Pittsburgh Pirates     -208.0      190.0
# 4  Philadelphia Phillies      Atlanta Braves     -115.0      105.0
#
#         bookmaker _merge
# 0          betmgm   both
# 1          betmgm   both
# 2          betmgm   both
# 3  williamhill_us   both
# 4          betmgm   both

# %%
df_games_m['_merge'].value_counts(dropna=False)
# Out:
# _merge
# both          12007
# left_only      1965
# right_only        0
# Name: count, dtype: int64

# %%
df_games_m['_merge'].value_counts(dropna=False, normalize=True)[:-1].round(3)
# Out:
# _merge
# both         0.858
# left_only    0.142
# Name: proportion, dtype: float64

# %%
df_games_m['season'] = df_games_m['game_date'].dt.year
df_games_m.groupby('season')['_merge'].value_counts(dropna=False)
# Out:
# season  _merge
# 2021    both          2104
#         left_only      532
#         right_only       0
# 2022    both          2309
#         left_only      425
#         right_only       0
# 2023    both          3638
#         left_only      413
#         right_only       0
# 2024    both          2471
#         left_only      335
#         right_only       0
# 2025    both          1485
#         left_only      260
#         right_only       0
# Name: count, dtype: int64

# %%
df_games_m.groupby('season')['_merge'].value_counts(dropna=False, normalize=True)
# Out:
# season  _merge
# 2021    both          0.798179
#         left_only     0.201821
#         right_only    0.000000
# 2022    both          0.844550
#         left_only     0.155450
#         right_only    0.000000
# 2023    both          0.898050
#         left_only     0.101950
#         right_only    0.000000
# 2024    both          0.880613
#         left_only     0.119387
#         right_only    0.000000
# 2025    both          0.851003
#         left_only     0.148997
#         right_only    0.000000
# Name: proportion, dtype: float64

# %%
df_games_m[(df_games_m['game_date_time'] != df_games_m['commence_time']) & (df_games_m['_merge']=='both')].shape
# Out:
# (6824, 18)

# %%
df_games_m[(df_games_m['game_date_time'] != df_games_m['commence_time']) & (df_games_m['_merge']=='both')].head(10)
# Out:
#     game_id  game_date            game_date_time  home_team_id  away_team_id  \
# 15   634631 2021-04-02 2021-04-03 01:38:00+00:00           108           145
# 16   634605 2021-04-02 2021-04-03 01:40:00+00:00           133           117
# 18   634578 2021-04-02 2021-04-03 02:10:00+00:00           136           137
# 19   634644 2021-04-03 2021-04-03 17:05:00+00:00           147           141
# 20   634577 2021-04-03 2021-04-03 17:10:00+00:00           111           110
# 21   634573 2021-04-03 2021-04-03 17:10:00+00:00           116           114
# 23   634643 2021-04-03 2021-04-03 18:20:00+00:00           112           134
# 24   634580 2021-04-03 2021-04-03 20:05:00+00:00           143           144
# 25   634629 2021-04-03 2021-04-03 20:07:00+00:00           133           117
# 27   634654 2021-04-03 2021-04-03 20:10:00+00:00           113           138
#
#                 home_team             away_team  home_score  away_score  \
# 15     Los Angeles Angels     Chicago White Sox         8.0        12.0
# 16      Oakland Athletics        Houston Astros         5.0         9.0
# 18       Seattle Mariners  San Francisco Giants         3.0         6.0
# 19       New York Yankees     Toronto Blue Jays         5.0         3.0
# 20         Boston Red Sox     Baltimore Orioles         2.0         4.0
# 21         Detroit Tigers     Cleveland Indians         5.0         2.0
# 23           Chicago Cubs    Pittsburgh Pirates         5.0         1.0
# 24  Philadelphia Phillies        Atlanta Braves         4.0         0.0
# 25      Oakland Athletics        Houston Astros         1.0         9.0
# 27        Cincinnati Reds   St. Louis Cardinals         9.0         6.0
#
#     state                     venue game_type                 timestamp  \
# 15  Final             Angel Stadium         R 2021-04-01 12:55:00+00:00
# 16  Final          Oakland Coliseum         R 2021-04-01 12:55:00+00:00
# 18  Final             T-Mobile Park         R 2021-04-01 12:55:00+00:00
# 19  Final            Yankee Stadium         R 2021-04-03 12:55:00+00:00
# 20  Final               Fenway Park         R 2021-04-03 12:55:00+00:00
# 21  Final             Comerica Park         R 2021-04-03 12:55:00+00:00
# 23  Final             Wrigley Field         R 2021-04-03 12:55:00+00:00
# 24  Final        Citizens Bank Park         R 2021-04-03 12:55:00+00:00
# 25  Final          Oakland Coliseum         R 2021-04-02 12:55:00+00:00
# 27  Final  Great American Ball Park         R 2021-04-03 12:55:00+00:00
#
#                commence_time       bookmaker  home_odds  away_odds _merge
# 15 2021-04-02 02:05:00+00:00          betmgm      105.0     -115.0   both
# 16 2021-04-02 02:07:00+00:00          betmgm     -105.0     -105.0   both
# 18 2021-04-02 02:10:00+00:00          betmgm     -105.0     -105.0   both
# 19 2021-04-03 17:06:00+00:00          betmgm     -175.0      145.0   both
# 20 2021-04-03 17:11:00+00:00  williamhill_us     -172.0      157.0   both
# 21 2021-04-03 17:11:00+00:00          betmgm      145.0     -175.0   both
# 23 2021-04-03 18:21:00+00:00  williamhill_us     -161.0      150.0   both
# 24 2021-04-03 20:06:00+00:00  williamhill_us      101.0     -111.0   both
# 25 2021-04-03 01:41:00+00:00  williamhill_us     -141.0      130.0   both
# 27 2021-04-03 20:11:00+00:00          betmgm     -115.0     -105.0   both

# %%
df_games_m['time_diff'] = (df_games_m['game_date_time'] - df_games_m['commence_time']).dt.total_seconds()/60
df_games_m['time_match'] = (df_games_m['time_diff'].abs() < 10).astype(int)
PREFERRED_BOOKMAKERS = ["betmgm", "draftkings", "fanduel", "williamhill_us", "espnbet"]
df_games_m['preferred_bookmaker'] = np.where(df_games_m['bookmaker'].isin(PREFERRED_BOOKMAKERS), 1, 0)

# %%
cols = ['game_id','game_date','game_date_time','commence_time','time_diff','time_match','home_team','away_team','bookmaker','preferred_bookmaker','home_odds','away_odds','_merge']
df_games_m[df_games_m['game_id'].duplicated(keep=False)][cols].head(12)
# Out:
#     game_id  game_date            game_date_time             commence_time  \
# 25   634629 2021-04-03 2021-04-03 20:07:00+00:00 2021-04-03 01:41:00+00:00
# 26   634629 2021-04-03 2021-04-03 20:07:00+00:00 2021-04-03 20:07:00+00:00
# 42   634557 2021-04-04 2021-04-04 19:10:00+00:00 2021-04-04 00:11:00+00:00
# 43   634557 2021-04-04 2021-04-04 19:10:00+00:00 2021-04-04 19:11:00+00:00
# 45   634572 2021-04-04 2021-04-04 20:10:00+00:00 2021-04-04 00:41:00+00:00
# 46   634572 2021-04-04 2021-04-04 20:10:00+00:00 2021-04-04 20:11:00+00:00
# 63   634586 2021-04-06 2021-04-06 20:07:00+00:00 2021-04-06 01:38:00+00:00
# 64   634586 2021-04-06 2021-04-06 20:07:00+00:00 2021-04-06 20:07:00+00:00
# 81   634583 2021-04-07 2021-04-07 18:05:00+00:00 2021-04-07 00:05:00+00:00
# 82   634583 2021-04-07 2021-04-07 18:05:00+00:00 2021-04-07 18:06:00+00:00
# 84   634567 2021-04-07 2021-04-07 19:37:00+00:00 2021-04-07 01:41:00+00:00
# 85   634567 2021-04-07 2021-04-07 19:37:00+00:00 2021-04-07 19:38:00+00:00
#
#     time_diff  time_match           home_team             away_team  \
# 25     1106.0           0   Oakland Athletics        Houston Astros
# 26        0.0           1   Oakland Athletics        Houston Astros
# 42     1139.0           0    Colorado Rockies   Los Angeles Dodgers
# 43       -1.0           1    Colorado Rockies   Los Angeles Dodgers
# 45     1169.0           0    San Diego Padres  Arizona Diamondbacks
# 46       -1.0           1    San Diego Padres  Arizona Diamondbacks
# 63     1109.0           0  Los Angeles Angels        Houston Astros
# 64        0.0           1  Los Angeles Angels        Houston Astros
# 81     1080.0           0       Texas Rangers     Toronto Blue Jays
# 82       -1.0           1       Texas Rangers     Toronto Blue Jays
# 84     1076.0           0   Oakland Athletics   Los Angeles Dodgers
# 85       -1.0           1   Oakland Athletics   Los Angeles Dodgers
#
#          bookmaker  preferred_bookmaker  home_odds  away_odds _merge
# 25  williamhill_us                    1     -141.0      130.0   both
# 26  williamhill_us                    1      110.0     -120.0   both
# 42          betmgm                    1      190.0     -250.0   both
# 43          betmgm                    1      190.0     -250.0   both
# 45         fanduel                    1     -213.0      180.0   both
# 46  williamhill_us                    1     -213.0      193.0   both
# 63  williamhill_us                    1     -115.0      105.0   both
# 64  williamhill_us                    1      105.0     -115.0   both
# 81  williamhill_us                    1      120.0     -130.0   both
# 82  williamhill_us                    1      170.0     -189.0   both
# 84  williamhill_us                    1      150.0     -161.0   both
# 85  williamhill_us                    1      147.0     -156.0   both

# %%
dups = df_games_m[df_games_m.duplicated(['game_id','preferred_bookmaker'],keep=False)][cols]

# %%
len(dups)
# Out:
# 5332

# %%
dups['game_id'].nunique()
# Out:
# 2359

# %%
len(dups[dups['time_match']==1]), dups[dups['time_match']==1]['game_id'].nunique()
# Out:
# (3533, 2228)

# %%
df_match = dups[dups['time_match']==1]

# %%
len(df_match), df_match['game_id'].nunique()
# Out:
# (3533, 2228)

# %%
df_match.groupby(['game_id','game_date_time'])['preferred_bookmaker'].agg('max').reset_index()['preferred_bookmaker'].value_counts(dropna=False)
# Out:
# preferred_bookmaker
# 1    2228
# Name: count, dtype: int64

# %%
df_match[df_match.duplicated('game_id',keep=False)].head(10)
# Out:
#      game_id  game_date            game_date_time             commence_time  \
# 144   632207 2021-04-11 2021-04-11 23:08:00+00:00 2021-04-11 23:08:00+00:00
# 145   632207 2021-04-11 2021-04-11 23:08:00+00:00 2021-04-11 23:09:00+00:00
# 297   634389 2021-04-23 2021-04-23 23:05:00+00:00 2021-04-23 23:05:00+00:00
# 298   634389 2021-04-23 2021-04-23 23:05:00+00:00 2021-04-23 23:06:00+00:00
# 299   634412 2021-04-23 2021-04-23 23:10:00+00:00 2021-04-23 23:10:00+00:00
# 300   634412 2021-04-23 2021-04-23 23:10:00+00:00 2021-04-23 23:11:00+00:00
# 301   634429 2021-04-23 2021-04-23 23:10:00+00:00 2021-04-23 23:10:00+00:00
# 302   634429 2021-04-23 2021-04-23 23:10:00+00:00 2021-04-23 23:11:00+00:00
# 304   634413 2021-04-23 2021-04-23 23:10:00+00:00 2021-04-23 23:10:00+00:00
# 305   634413 2021-04-23 2021-04-23 23:10:00+00:00 2021-04-23 23:11:00+00:00
#
#      time_diff  time_match          home_team              away_team  \
# 144        0.0           1     Atlanta Braves  Philadelphia Phillies
# 145       -1.0           1     Atlanta Braves  Philadelphia Phillies
# 297        0.0           1  Baltimore Orioles      Oakland Athletics
# 298       -1.0           1  Baltimore Orioles      Oakland Athletics
# 299        0.0           1     Detroit Tigers     Kansas City Royals
# 300       -1.0           1     Detroit Tigers     Kansas City Royals
# 301        0.0           1      New York Mets   Washington Nationals
# 302       -1.0           1      New York Mets   Washington Nationals
# 304        0.0           1     Tampa Bay Rays      Toronto Blue Jays
# 305       -1.0           1     Tampa Bay Rays      Toronto Blue Jays
#
#           bookmaker  preferred_bookmaker  home_odds  away_odds _merge
# 144      mybookieag                    0     -192.0      125.0   both
# 145  williamhill_us                    1     -156.0      147.0   both
# 297      mybookieag                    0      260.0     -370.0   both
# 298  williamhill_us                    1      120.0     -130.0   both
# 299      mybookieag                    0      145.0     -192.0   both
# 300  williamhill_us                    1      105.0     -115.0   both
# 301      mybookieag                    0     -286.0      204.0   both
# 302  williamhill_us                    1     -303.0      260.0   both
# 304      mybookieag                    0      440.0     -833.0   both
# 305  williamhill_us                    1     -154.0      143.0   both

# %%
df_deduplicated = df_games_m.groupby('game_id').apply(keep_preferred_bookmaker,include_groups=False).reset_index()

# %%
df_deduplicated.shape
# Out:
# (10968, 23)

# %%
df_deduplicated['game_id'].nunique()
# Out:
# 10968

# %%
df_deduplicated[df_deduplicated.duplicated('game_id',keep=False)][cols].describe()
# Out:
#        game_id game_date  time_diff  time_match  preferred_bookmaker  \
# count      0.0         0        0.0         0.0                  0.0
# mean       NaN       NaT        NaN         NaN                  NaN
# min        NaN       NaT        NaN         NaN                  NaN
# 25%        NaN       NaT        NaN         NaN                  NaN
# 50%        NaN       NaT        NaN         NaN                  NaN
# 75%        NaN       NaT        NaN         NaN                  NaN
# max        NaN       NaT        NaN         NaN                  NaN
# std        NaN       NaN        NaN         NaN                  NaN
#
#        home_odds  away_odds
# count        0.0        0.0
# mean         NaN        NaN
# min          NaN        NaN
# 25%          NaN        NaN
# 50%          NaN        NaN
# 75%          NaN        NaN
# max          NaN        NaN
# std          NaN        NaN

# %%
df_games_m[(df_games_m['game_id']==634029)][cols]
# Out:
#      game_id  game_date            game_date_time             commence_time  \
# 695   634029 2021-05-19 2021-05-20 00:07:00+00:00 2021-05-19 01:38:00+00:00
# 696   634029 2021-05-19 2021-05-20 00:07:00+00:00 2021-05-19 01:39:00+00:00
#
#      time_diff  time_match           home_team          away_team   bookmaker  \
# 695     1349.0           0  Los Angeles Angels  Cleveland Indians  mybookieag
# 696     1348.0           0  Los Angeles Angels  Cleveland Indians      betmgm
#
#      preferred_bookmaker  home_odds  away_odds _merge
# 695                    0     -141.0      120.0   both
# 696                    1     -145.0      120.0   both

# %%
def convert_odds_to_probability(odds: int) -> float:
    """Convert moneyline odds to implied probability"""
    if odds < 0:
        probability = abs(odds) / (100 + abs(odds))
    else:
        probability = 100 / (100 + odds)
    
    return probability

# %%
df_dedup.head(2)
# Out:
#    game_id  game_date            game_date_time  home_team_id  away_team_id  \
# 0   632169 2021-04-10 2021-04-10 20:05:00+00:00           137           115
# 1   632170 2021-04-11 2021-04-11 18:10:00+00:00           145           118
#
#               home_team           away_team  home_score  away_score  state  \
# 0  San Francisco Giants    Colorado Rockies         4.0         3.0  Final
# 1     Chicago White Sox  Kansas City Royals         3.0         4.0  Final
#
#                    venue game_type                 timestamp  \
# 0            Oracle Park         R 2021-04-10 12:55:00+00:00
# 1  Guaranteed Rate Field         R 2021-04-11 12:55:00+00:00
#
#               commence_time       bookmaker  home_odds  away_odds _merge  \
# 0 2021-04-10 20:05:00+00:00  williamhill_us     -179.0      162.0   both
# 1 2021-04-11 18:10:00+00:00  williamhill_us     -130.0      120.0   both
#
#    time_diff  time_match  preferred_bookmaker
# 0        0.0           1                    1
# 1        0.0           1                    1

# %%
df_dedup['home_implied_prob'] = df_dedup['home_odds'].apply(convert_odds_to_probability)

# %%
df_dedup.head(2)
# Out:
#    game_id  game_date            game_date_time  home_team_id  away_team_id  \
# 0   632169 2021-04-10 2021-04-10 20:05:00+00:00           137           115
# 1   632170 2021-04-11 2021-04-11 18:10:00+00:00           145           118
#
#               home_team           away_team  home_score  away_score  state  \
# 0  San Francisco Giants    Colorado Rockies         4.0         3.0  Final
# 1     Chicago White Sox  Kansas City Royals         3.0         4.0  Final
#
#                    venue game_type                 timestamp  \
# 0            Oracle Park         R 2021-04-10 12:55:00+00:00
# 1  Guaranteed Rate Field         R 2021-04-11 12:55:00+00:00
#
#               commence_time       bookmaker  home_odds  away_odds _merge  \
# 0 2021-04-10 20:05:00+00:00  williamhill_us     -179.0      162.0   both
# 1 2021-04-11 18:10:00+00:00  williamhill_us     -130.0      120.0   both
#
#    time_diff  time_match  preferred_bookmaker  home_implied_prob
# 0        0.0           1                    1           0.641577
# 1        0.0           1                    1           0.565217

# %%
float(convert_odds_to_probability(df_dedup['home_odds'].iloc[:3]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2j/knnjq0x51sddhsfjqdw6wpl40000gn/T/ipykernel_771/2277968529.py in ?()
# ----> 1 float(convert_odds_to_probability(df_dedup['home_odds'].iloc[:3]))
#
# /var/folders/2j/knnjq0x51sddhsfjqdw6wpl40000gn/T/ipykernel_771/3934319932.py in ?(odds)
#       1 def convert_odds_to_probability(odds: int) -> float:
#       2     """Convert moneyline odds to implied probability"""
# ----> 3     if odds < 0:
#       4         probability = abs(odds) / (100 + abs(odds))
#       5     else:
#       6         probability = 100 / (100 + odds)
#
# ~/Library/CloudStorage/OneDrive-Personal/GitHub/end-to-end-mlb-betting/.venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
